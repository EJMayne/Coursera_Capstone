# %% [markdown]
# # Battle of Neighbourhoods

# %% [markdown]
# ## Introduction/Background

# %% [markdown]
# Mrs A has decided to open a new Italian restaurant in London, having moved from Italy but she has not yet decided on the location. Mrs A wants to find the neighbourhood with successful existing restaurants to ensure there is high enough footfall, however she does not want there to be too much direct competition from other nearby Italian restaurants.
# This data science problem will be addressed with Mrs A as the target audience to help her decide where the best location for her new Italian restaurant will be.

# %% [markdown]
# There are multiple factors to consider in the approach to this problem. These include the number of similar restaurants in the immediate area (here we will use a 500m radius), the success of other food businesses and the affluence of the area in general.

# %%
import pandas as pd
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium 
import requests
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim

# %% [markdown]
# Read in csv containing postcodes for each ward within each district (obtained from https://www.doogal.co.uk/london_postcodes.php) as a pandas dataframe:

# %%
pcRaw = pd.read_csv(r'~\Documents\London postcodes.csv')
pcRaw.head()
# Out:
# C:\Users\Eilidh.Mayne\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Postcode In Use?   Latitude  Longitude  Easting  Northing  Grid Ref  \
# 0  BR1 1AA     Yes  51.401546   0.015415   540291    168873  TQ402688
# 1  BR1 1AB     Yes  51.406333   0.015208   540262    169405  TQ402694
# 2  BR1 1AD      No  51.400057   0.016715   540386    168710  TQ403687
# 3  BR1 1AE     Yes  51.404543   0.014195   540197    169204  TQ401692
# 4  BR1 1AF     Yes  51.401392   0.014948   540259    168855  TQ402688
#
#            County District          Ward  ... Nearest station  \
# 0  Greater London  Bromley  Bromley Town  ...   Bromley South
# 1  Greater London  Bromley  Bromley Town  ...   Bromley North
# 2  Greater London  Bromley  Bromley Town  ...   Bromley South
# 3  Greater London  Bromley  Bromley Town  ...   Bromley North
# 4  Greater London  Bromley  Bromley Town  ...   Bromley South
#
#   Distance to station Postcode area Postcode district         Police force  \
# 0            0.218257            BR               BR1  Metropolitan Police
# 1            0.253666            BR               BR1  Metropolitan Police
# 2            0.044559            BR               BR1  Metropolitan Police
# 3            0.462939            BR               BR1  Metropolitan Police
# 4            0.227664            BR               BR1  Metropolitan Police
#
#   Water company    Plus Code Average Income  Sewage Company  \
# 0  Thames Water  9F32C228+J5          63100             NaN
# 1  Thames Water  9F32C248+G3          56100             NaN
# 2           NaN  9F32C228+2M          63100             NaN
# 3  Thames Water  9F32C237+RM          63100             NaN
# 4  Thames Water  9F32C227+HX          63100             NaN
#
#    Travel To Work Area
# 0               London
# 1               London
# 2               London
# 3               London
# 4               London
#
# [5 rows x 49 columns]

# %% [markdown]
# We only want the Postcode, District, Ward, Latitude and Longitude columns in our dataframe so let's initialise this as a new dataframe, 'postcodes':

# %%
postcodes = pcRaw[['Postcode','District','Ward','Latitude','Longitude']]
postcodes.head()
# Out:
#   Postcode District          Ward   Latitude  Longitude
# 0  BR1 1AA  Bromley  Bromley Town  51.401546   0.015415
# 1  BR1 1AB  Bromley  Bromley Town  51.406333   0.015208
# 2  BR1 1AD  Bromley  Bromley Town  51.400057   0.016715
# 3  BR1 1AE  Bromley  Bromley Town  51.404543   0.014195
# 4  BR1 1AF  Bromley  Bromley Town  51.401392   0.014948

# %% [markdown]
# Let's look at the shape of the dataframe to see how many postcodes we have:

# %%
postcodes.shape
# Out:
# (323306, 5)

# %% [markdown]
# We have 323,306 postcodes in total! As this is a large number, we first want to narrow down our data to just the district with the highest GDHI, so let's import the dataset for this now.

# %% [markdown]
# Get Regional Gross Disposable Household Income dataset from the gov website: (https://www.ons.gov.uk/economy/regionalaccounts/grossdisposablehouseholdincome/datasets/regionalgrossdisposablehouseholdincomebylocalauthoritiesbynuts1region)

# %%
gdhi = pd.read_excel(r"~/Documents/regionalgrossdisposablehouseholdincomelocalauthorityukilondon.xls", sheet_name="Table 1", skiprows=1)
gdhi.rename(columns={"20182": 2018},inplace=True)
gdhi.dropna(inplace=True)
gdhi.head()
# Out:
#    Region   LAD code             Region name    1997    1998    1999    2000  \
# 0  London  E09000001          City of London   462.0   514.0   543.0   603.0
# 1  London  E09000007                  Camden  3050.0  3348.0  3697.0  4236.0
# 2  London  E09000033             Westminster  3813.0  4044.0  4496.0  5118.0
# 3  London  E09000013  Hammersmith and Fulham  2894.0  2948.0  3208.0  3559.0
# 4  London  E09000020  Kensington and Chelsea  5358.0  5359.0  5702.0  6389.0
#
#      2001    2002    2003  ...     2009    2010    2011     2012     2013  \
# 0   625.0   627.0   646.0  ...   1036.0   992.0   989.0   1075.0   1202.0
# 1  4373.0  4401.0  4510.0  ...   7450.0  7222.0  7134.0   7813.0   8710.0
# 2  5353.0  5435.0  5623.0  ...   8980.0  8789.0  8741.0   9588.0  10671.0
# 3  3657.0  3657.0  3757.0  ...   5613.0  5549.0  5366.0   5759.0   6411.0
# 4  6569.0  6529.0  6712.0  ...  10171.0  9763.0  9527.0  10380.0  11589.0
#
#       2014     2015     2016     2017     2018
# 0   1296.0   1426.0   1462.0   1487.0   1673.0
# 1   9151.0   9954.0  10332.0  10274.0  11170.0
# 2  11460.0  12674.0  12906.0  13190.0  14004.0
# 3   6801.0   7140.0   7004.0   7082.0   7587.0
# 4  12533.0  13097.0  12764.0  12841.0  14033.0
#
# [5 rows x 25 columns]

# %% [markdown]
# Unfortunately, the dataset only includes data up to 2018 so there are a couple of years missing. Because of this, we will look at the average GDHI over the last five years in the dataset (2014 - 2018) and take the highest.

# %%
gdhi = gdhi[['Region name', 2014,2015,2016,2017,2018]]
gdhi['avg_5_yr'] = gdhi[[2014,2015,2016,2017,2018]].mean(axis=1)

# %% [markdown]
# Let's look at the first 5 rows of our dataset with the new column 'avg_5_yr':

# %%
gdhi.head()
# Out:
#               Region name     2014     2015     2016     2017     2018  \
# 0          City of London   1296.0   1426.0   1462.0   1487.0   1673.0
# 1                  Camden   9151.0   9954.0  10332.0  10274.0  11170.0
# 2             Westminster  11460.0  12674.0  12906.0  13190.0  14004.0
# 3  Hammersmith and Fulham   6801.0   7140.0   7004.0   7082.0   7587.0
# 4  Kensington and Chelsea  12533.0  13097.0  12764.0  12841.0  14033.0
#
#    avg_5_yr
# 0    1468.8
# 1   10176.2
# 2   12846.8
# 3    7122.8
# 4   13053.6

# %% [markdown]
# Now we need to find the region with the highest GDHI:

# %%
region_name = gdhi.loc[gdhi['avg_5_yr']==gdhi['avg_5_yr'].max(), 'Region name']
region_name
# Out:
# 4    Kensington and Chelsea
# Name: Region name, dtype: object

# %% [markdown]
# We will now filter the postcodes dataset to just the rows for Kensington and Chelsea:

# %%
KC_postcodes = postcodes[postcodes['District']=='Kensington and Chelsea'].reset_index(drop=True)
KC_postcodes
# Out:
#       Postcode                District               Ward   Latitude  \
# 0     SW10 0AB  Kensington and Chelsea  Chelsea Riverside  51.478206
# 1     SW10 0AD  Kensington and Chelsea            Stanley  51.485945
# 2     SW10 0AE  Kensington and Chelsea            Stanley  51.485776
# 3     SW10 0AF  Kensington and Chelsea            Stanley  51.481480
# 4     SW10 0AG  Kensington and Chelsea            Stanley  51.485807
# ...        ...                     ...                ...        ...
# 8481    W9 4HS  Kensington and Chelsea           Abingdon  51.498289
# 8482    W9 4HT  Kensington and Chelsea           Abingdon  51.498289
# 8483    W9 4HU  Kensington and Chelsea           Abingdon  51.498289
# 8484    W9 4HW  Kensington and Chelsea           Abingdon  51.498289
# 8485    W9 4HY  Kensington and Chelsea           Abingdon  51.498289
#
#       Longitude
# 0     -0.183053
# 1     -0.180470
# 2     -0.180621
# 3     -0.183053
# 4     -0.180317
# ...         ...
# 8481  -0.198295
# 8482  -0.198295
# 8483  -0.198295
# 8484  -0.198295
# 8485  -0.198295
#
# [8486 rows x 5 columns]

# %% [markdown]
# That's looking a little more manageable with 8,486 postcodes however it would look very busy on a map so it would be helpful to have one postcode for each Ward. Let's check how many Wards (neighbourhoods) there are:

# %%
KC_postcodes['Ward'].nunique()
# Out:
# 18

# %%
KC_postcodes['Ward'].unique()
# Out:
# array(['Chelsea Riverside', 'Stanley', 'Redcliffe', 'Courtfield',
#        'Abingdon', 'Royal Hospital', 'Brompton & Hans Town',
#        "Earl's Court", "Queen's Gate", 'Dalgarno', 'Golborne', 'Colville',
#        "St. Helen's", 'Notting Dale', 'Norland', 'Pembridge', 'Campden',
#        'Holland'], dtype=object)

# %% [markdown]
# We will iterate through each of the Wards listed above and obtain the coordiates using the geopy library. Empty lists have been initialised and the ward names and coordinates will be appended to these:

# %%
ward = []
lat = []
long = []

for i in KC_postcodes['Ward'].unique():
    
    address = i+', Kensington and Chelsea, London'

    geolocator = Nominatim(user_agent="London_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    ward.append(i)
    lat.append(latitude)
    long.append(longitude)
    KC_data = pd.DataFrame({'Ward': ward,'Latitude': lat,'Longitude': long})

KC_data
# Out:
#                     Ward   Latitude  Longitude
# 0      Chelsea Riverside  51.487542  -0.168220
# 1                Stanley  51.512145  -0.204227
# 2              Redcliffe  51.488203  -0.188386
# 3             Courtfield  51.492211  -0.192594
# 4               Abingdon  51.497579  -0.196173
# 5         Royal Hospital  51.487094  -0.158674
# 6   Brompton & Hans Town  51.497304  -0.168841
# 7           Earl's Court  51.491612  -0.193903
# 8           Queen's Gate  51.493364  -0.178546
# 9               Dalgarno  51.523419  -0.223709
# 10              Golborne  51.522295  -0.207622
# 11              Colville  51.515728  -0.203766
# 12           St. Helen's  51.518820  -0.218068
# 13          Notting Dale  51.510819  -0.218484
# 14               Norland  51.506093  -0.211574
# 15             Pembridge  51.511258  -0.195188
# 16               Campden  51.508636  -0.199788
# 17               Holland  51.503008  -0.204135

# %% [markdown]
# We now have the coordinates for each Ward. Let's go ahead and plot these on a map, using the geopy library:

# %%
map_KC = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(KC_data['Latitude'], KC_data['Longitude'], KC_data['Ward']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_KC)  
    
map_KC
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We now need to obtain details for all restaurants in a 500m radius of each of the coordinates so we will make an API call to Foursquare:

# %%
CLIENT_ID = 'A4ZHKOHUHIVQ4D0AHZFVNLAQHBWU43JQVBRCUXN5KYXKKOPD'
CLIENT_SECRET = '2IOQ1YMRGCAIZ5NNL13MAI3PKKBLBQWBLWLKOAZGVIZZONBM'
AccessCode = "MD0Q44JWJGS0CNQNBW1M05U4Z0ACCOJT0UN12NII2JTGOWOF"
VERSION = '20180604'
LIMIT = 100

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):

        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius)

        results = requests.get(url).json()["response"]['groups'][0]['items']

        venues_list.append([(
            name, 
            lat, 
            lng,
            v['venue']['name'],
            v['venue']['id'],
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue',
                  'Venue_id',
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

KC_venues = getNearbyVenues(names=KC_data['Ward'],
                                   latitudes=KC_data['Latitude'],
                                   longitudes=KC_data['Longitude']
                                  )

# %% [markdown]
# Let's see how many venue categories we have in the area:

# %%
KC_venues['Venue Category'].nunique()
# Out:
# 132

# %% [markdown]
# And list them out:

# %%
KC_venues['Venue Category'].unique()
# Out:
# array(["Women's Store", 'Vietnamese Restaurant', 'Coffee Shop',
#        'English Restaurant', 'Garden Center', 'Supermarket', 'Bakery',
#        'Bookstore', 'Café', 'Gym / Fitness Center', 'Creperie', 'Park',
#        'Shopping Plaza', 'Ice Cream Shop', 'Art Gallery', 'Restaurant',
#        'Japanese Restaurant', 'Burger Joint', 'Plaza', 'Juice Bar',
#        'Italian Restaurant', 'Cupcake Shop', 'French Restaurant',
#        'Boxing Gym', 'Garden', 'Boutique', 'Bar', 'Market', 'Candy Store',
#        'Clothing Store', 'Antique Shop', 'Movie Theater', 'Gastropub',
#        'Pub', 'Gym', 'Gourmet Shop', 'Breakfast Spot', 'Cocktail Bar',
#        'Diner', 'Australian Restaurant', 'Cheese Shop', 'Speakeasy',
#        'Pizza Place', 'Indie Theater', 'Farmers Market',
#        'Tapas Restaurant', 'Hotel', 'Grocery Store', 'Road',
#        'Middle Eastern Restaurant', 'Thai Restaurant',
#        'Indian Restaurant', 'Fast Food Restaurant', 'Hookah Bar',
#        'Lebanese Restaurant', 'Pilates Studio', 'Historic Site',
#        'Modern European Restaurant', 'Mediterranean Restaurant',
#        'Sushi Restaurant', 'Museum', 'Gift Shop', 'Recording Studio',
#        'History Museum', 'Persian Restaurant', 'Sporting Goods Shop',
#        'Harbor / Marina', 'Deli / Bodega', 'Sandwich Place', 'Tea Room',
#        'Department Store', 'Steakhouse', 'Art Museum',
#        'Turkish Restaurant', 'Residential Building (Apartment / Condo)',
#        'Science Museum', 'College Quad', 'Exhibit', 'Pharmacy',
#        'Chocolate Shop', 'Jewelry Store', 'Dessert Shop', 'Yoga Studio',
#        'Social Club', 'Seafood Restaurant', 'Indie Movie Theater',
#        'Kebab Restaurant', 'Wine Shop', 'Portuguese Restaurant',
#        'Convenience Store', 'Chinese Restaurant', 'Bus Stop',
#        'Playground', 'Fish & Chips Shop', 'Skate Park', 'Record Shop',
#        'Thrift / Vintage Store', 'Street Food Gathering', 'Donut Shop',
#        'Beer Bar', 'Food & Drink Shop', 'Canal', 'Athletics & Sports',
#        'Music Venue', 'Asian Restaurant', 'Indoor Play Area',
#        'Theme Park Ride / Attraction', 'Cosmetics Shop', 'Mini Golf',
#        'Shopping Mall', 'Electronics Store', 'Toy / Game Store',
#        'Lingerie Store', 'Frozen Yogurt Shop', 'Multiplex',
#        'Stationery Store', 'Shoe Store', 'Massage Studio', 'Butcher',
#        'Bubble Tea Shop', 'Hotel Bar', 'Tennis Court', 'Wine Bar',
#        'Ukrainian Restaurant', 'Greek Restaurant', 'Nail Salon',
#        'Cycle Studio', 'Opera House', 'Hostel', 'Pedestrian Plaza',
#        'Metro Station', 'Outdoor Sculpture'], dtype=object)

# %% [markdown]
# There are a few in here that are restaurants so we want to filter the KC_venues dataframe to only include these.

# %%
KC_restaurants = KC_venues[KC_venues['Venue Category'].str.contains('Restaurant')]
KC_restaurants.head()
# Out:
#          Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 1   Chelsea Riverside              51.487542                -0.16822
# 3   Chelsea Riverside              51.487542                -0.16822
# 16  Chelsea Riverside              51.487542                -0.16822
# 17  Chelsea Riverside              51.487542                -0.16822
# 18  Chelsea Riverside              51.487542                -0.16822
#
#                                 Venue                  Venue_id  \
# 1                Phật Phúc Noodle Bar  4b8678d8f964a5208f8b31e3
# 3              The Ivy Chelsea Garden  55197d88498e3f4d85dc801c
# 16  Bye Bye London Kuwaiti Restuarant  5bd4a3251a29250025225b02
# 17                        Oka Chelsea  568e9345498eb6c01aa9e930
# 18                     Sticks'n'Sushi  5bad2872666116002c429f44
#
#     Venue Latitude  Venue Longitude         Venue Category
# 1        51.487620        -0.169044  Vietnamese Restaurant
# 3        51.487035        -0.169379     English Restaurant
# 16       51.487863        -0.167752             Restaurant
# 17       51.486224        -0.172009    Japanese Restaurant
# 18       51.488670        -0.165713    Japanese Restaurant

# %% [markdown]
# As we're dealing with categorical data we want to use one hot encoding to convert it to numerical and allow us to carry out statistical testing on the data:

# %%
KC_onehot = pd.get_dummies(KC_restaurants[['Venue Category']], prefix="", prefix_sep="")
KC_onehot['Neighborhood'] = KC_restaurants['Neighborhood'] 
fixed_columns = [KC_onehot.columns[-1]] + list(KC_onehot.columns[:-1])
KC_onehot = KC_onehot[fixed_columns]
KC_onehot.head()
# Out:
#          Neighborhood  Asian Restaurant  Australian Restaurant  \
# 1   Chelsea Riverside                 0                      0
# 3   Chelsea Riverside                 0                      0
# 16  Chelsea Riverside                 0                      0
# 17  Chelsea Riverside                 0                      0
# 18  Chelsea Riverside                 0                      0
#
#     Chinese Restaurant  English Restaurant  Fast Food Restaurant  \
# 1                    0                   0                     0
# 3                    0                   1                     0
# 16                   0                   0                     0
# 17                   0                   0                     0
# 18                   0                   0                     0
#
#     French Restaurant  Greek Restaurant  Indian Restaurant  \
# 1                   0                 0                  0
# 3                   0                 0                  0
# 16                  0                 0                  0
# 17                  0                 0                  0
# 18                  0                 0                  0
#
#     Italian Restaurant  ...  Persian Restaurant  Portuguese Restaurant  \
# 1                    0  ...                   0                      0
# 3                    0  ...                   0                      0
# 16                   0  ...                   0                      0
# 17                   0  ...                   0                      0
# 18                   0  ...                   0                      0
#
#     Restaurant  Seafood Restaurant  Sushi Restaurant  Tapas Restaurant  \
# 1            0                   0                 0                 0
# 3            0                   0                 0                 0
# 16           1                   0                 0                 0
# 17           0                   0                 0                 0
# 18           0                   0                 0                 0
#
#     Thai Restaurant  Turkish Restaurant  Ukrainian Restaurant  \
# 1                 0                   0                     0
# 3                 0                   0                     0
# 16                0                   0                     0
# 17                0                   0                     0
# 18                0                   0                     0
#
#     Vietnamese Restaurant
# 1                       1
# 3                       0
# 16                      0
# 17                      0
# 18                      0
#
# [5 rows x 26 columns]

# %% [markdown]
# Now to combine the duplicate records for a neighbourhood (there is one row per venue currently), we take the mean for each venue type in each neighbourhood.

# %%
KC_grouped = KC_onehot.groupby('Neighborhood').mean().reset_index()
KC_grouped.head()
# Out:
#            Neighborhood  Asian Restaurant  Australian Restaurant  \
# 0              Abingdon          0.000000                    0.0
# 1  Brompton & Hans Town          0.000000                    0.0
# 2               Campden          0.000000                    0.0
# 3     Chelsea Riverside          0.000000                    0.0
# 4              Colville          0.142857                    0.0
#
#    Chinese Restaurant  English Restaurant  Fast Food Restaurant  \
# 0                 0.0            0.000000                   0.0
# 1                 0.0            0.000000                   0.0
# 2                 0.0            0.142857                   0.0
# 3                 0.0            0.125000                   0.0
# 4                 0.0            0.000000                   0.0
#
#    French Restaurant  Greek Restaurant  Indian Restaurant  Italian Restaurant  \
# 0           0.000000          0.000000           0.000000            0.375000
# 1           0.166667          0.000000           0.000000            0.333333
# 2           0.000000          0.142857           0.285714            0.142857
# 3           0.125000          0.000000           0.000000            0.250000
# 4           0.000000          0.000000           0.000000            0.571429
#
#    ...  Persian Restaurant  Portuguese Restaurant  Restaurant  \
# 0  ...               0.125               0.000000    0.000000
# 1  ...               0.000               0.000000    0.166667
# 2  ...               0.000               0.142857    0.000000
# 3  ...               0.000               0.000000    0.125000
# 4  ...               0.000               0.000000    0.285714
#
#    Seafood Restaurant  Sushi Restaurant  Tapas Restaurant  Thai Restaurant  \
# 0                 0.0          0.125000               0.0              0.0
# 1                 0.0          0.000000               0.0              0.0
# 2                 0.0          0.142857               0.0              0.0
# 3                 0.0          0.000000               0.0              0.0
# 4                 0.0          0.000000               0.0              0.0
#
#    Turkish Restaurant  Ukrainian Restaurant  Vietnamese Restaurant
# 0            0.000000                   0.0                  0.000
# 1            0.166667                   0.0                  0.000
# 2            0.000000                   0.0                  0.000
# 3            0.000000                   0.0                  0.125
# 4            0.000000                   0.0                  0.000
#
# [5 rows x 26 columns]

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = KC_grouped['Neighborhood']

for ind in np.arange(KC_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(KC_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#             Neighborhood 1st Most Common Venue     2nd Most Common Venue  \
# 0               Abingdon    Italian Restaurant  Mediterranean Restaurant
# 1   Brompton & Hans Town    Italian Restaurant        Turkish Restaurant
# 2                Campden     Indian Restaurant        English Restaurant
# 3      Chelsea Riverside    Italian Restaurant       Japanese Restaurant
# 4               Colville    Italian Restaurant                Restaurant
# 5             Courtfield       Thai Restaurant      Fast Food Restaurant
# 6               Dalgarno       Thai Restaurant        Chinese Restaurant
# 7           Earl's Court       Thai Restaurant      Fast Food Restaurant
# 8               Golborne       Thai Restaurant        English Restaurant
# 9                Holland            Restaurant       Japanese Restaurant
# 10               Norland  Fast Food Restaurant        Italian Restaurant
# 11          Notting Dale    Chinese Restaurant         Indian Restaurant
# 12             Pembridge      Greek Restaurant        Persian Restaurant
# 13          Queen's Gate    Italian Restaurant     Vietnamese Restaurant
# 14             Redcliffe      Tapas Restaurant         French Restaurant
# 15        Royal Hospital    Italian Restaurant         French Restaurant
# 16               Stanley    Italian Restaurant                Restaurant
#
#     3rd Most Common Venue      4th Most Common Venue  \
# 0        Sushi Restaurant         Persian Restaurant
# 1              Restaurant          French Restaurant
# 2        Sushi Restaurant      Portuguese Restaurant
# 3   Vietnamese Restaurant         English Restaurant
# 4        Asian Restaurant        Lebanese Restaurant
# 5       Indian Restaurant         Italian Restaurant
# 6   Vietnamese Restaurant        Lebanese Restaurant
# 7       Indian Restaurant         Italian Restaurant
# 8      Italian Restaurant  Middle Eastern Restaurant
# 9   Vietnamese Restaurant        Lebanese Restaurant
# 10    Japanese Restaurant       Ukrainian Restaurant
# 11  Vietnamese Restaurant        Lebanese Restaurant
# 12     Italian Restaurant      Australian Restaurant
# 13     Seafood Restaurant        Japanese Restaurant
# 14             Restaurant         Italian Restaurant
# 15             Restaurant        Japanese Restaurant
# 16  Australian Restaurant      Vietnamese Restaurant
#
#          5th Most Common Venue      6th Most Common Venue  \
# 0   Modern European Restaurant  Middle Eastern Restaurant
# 1          Japanese Restaurant      Vietnamese Restaurant
# 2             Greek Restaurant         Italian Restaurant
# 3            French Restaurant                 Restaurant
# 4        Australian Restaurant         Chinese Restaurant
# 5    Middle Eastern Restaurant        Japanese Restaurant
# 6        Australian Restaurant         English Restaurant
# 7    Middle Eastern Restaurant        Japanese Restaurant
# 8          Lebanese Restaurant      Vietnamese Restaurant
# 9        Australian Restaurant         Chinese Restaurant
# 10       Vietnamese Restaurant        Lebanese Restaurant
# 11       Australian Restaurant         English Restaurant
# 12          English Restaurant      Portuguese Restaurant
# 13            Kebab Restaurant      Portuguese Restaurant
# 14       Vietnamese Restaurant           Kebab Restaurant
# 15       Vietnamese Restaurant        Lebanese Restaurant
# 16         Lebanese Restaurant         Chinese Restaurant
#
#        7th Most Common Venue  8th Most Common Venue  9th Most Common Venue  \
# 0        Japanese Restaurant  Australian Restaurant     Chinese Restaurant
# 1           Kebab Restaurant  Australian Restaurant     Chinese Restaurant
# 2      Vietnamese Restaurant       Kebab Restaurant  Australian Restaurant
# 3        Lebanese Restaurant  Australian Restaurant     Chinese Restaurant
# 4         English Restaurant   Fast Food Restaurant      French Restaurant
# 5        Lebanese Restaurant  Vietnamese Restaurant       Kebab Restaurant
# 6       Fast Food Restaurant      French Restaurant       Greek Restaurant
# 7        Lebanese Restaurant  Vietnamese Restaurant       Kebab Restaurant
# 8           Kebab Restaurant  Australian Restaurant     Chinese Restaurant
# 9         English Restaurant   Fast Food Restaurant      French Restaurant
# 10     Australian Restaurant     Chinese Restaurant     English Restaurant
# 11      Fast Food Restaurant      French Restaurant       Greek Restaurant
# 12     Vietnamese Restaurant       Kebab Restaurant     Chinese Restaurant
# 13  Mediterranean Restaurant       Sushi Restaurant             Restaurant
# 14     Australian Restaurant     Chinese Restaurant     English Restaurant
# 15     Australian Restaurant     Chinese Restaurant     English Restaurant
# 16        English Restaurant   Fast Food Restaurant      French Restaurant
#
#    10th Most Common Venue
# 0      English Restaurant
# 1      English Restaurant
# 2      Chinese Restaurant
# 3    Fast Food Restaurant
# 4        Greek Restaurant
# 5   Australian Restaurant
# 6       Indian Restaurant
# 7   Australian Restaurant
# 8    Fast Food Restaurant
# 9        Greek Restaurant
# 10      French Restaurant
# 11     Italian Restaurant
# 12   Fast Food Restaurant
# 13  Australian Restaurant
# 14   Fast Food Restaurant
# 15   Fast Food Restaurant
# 16       Greek Restaurant

# %% [markdown]
# From the dataframe above we can see that Italian restaurants are very common in quite a few of the neighbourhoods. As we want to find a location for the restaurant where there is limited competition from nearby Italian restaurants we need to only look further into those neighbourhoods in which Italian restaurants are not very common.

# %%
high_comp_neighbourhoods = np.column_stack([neighborhoods_venues_sorted[col].str.contains(r"Italian Restaurant", na=False) for col in neighborhoods_venues_sorted])
low_comp_neighbourhoods = neighborhoods_venues_sorted.loc[~high_comp_neighbourhoods.any(axis=1)].reset_index(drop=True)
low_comp_neighbourhoods
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0     Dalgarno       Thai Restaurant    Chinese Restaurant
# 1      Holland            Restaurant   Japanese Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0  Vietnamese Restaurant   Lebanese Restaurant  Australian Restaurant
# 1  Vietnamese Restaurant   Lebanese Restaurant  Australian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0    English Restaurant  Fast Food Restaurant     French Restaurant
# 1    Chinese Restaurant    English Restaurant  Fast Food Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Greek Restaurant      Indian Restaurant
# 1     French Restaurant       Greek Restaurant

# %% [markdown]
# We have now isolated two neighbourhoods in which Italian restaurants are not common - Dalgarno and Holland. Let's look at the restaurants in both of these neighborhoods:

# %%
dalgarno_restaurants = KC_restaurants[KC_restaurants['Neighborhood']=='Dalgarno']
dalgarno_restaurants
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude         Venue  \
# 267     Dalgarno              51.523419               -0.223709       Fitou's
# 271     Dalgarno              51.523419               -0.223709  Fortune Star
#
#                      Venue_id  Venue Latitude  Venue Longitude  \
# 267  4bd1909b9854d13a39b6f94d       51.521973        -0.226575
# 271  4eba793ccc21a9a7a1e1dfe1       51.522594        -0.221408
#
#          Venue Category
# 267     Thai Restaurant
# 271  Chinese Restaurant

# %%
holland_restaurants = KC_restaurants[KC_restaurants['Neighborhood']=='Holland']
holland_restaurants
# Out:
#     Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 470      Holland              51.503008               -0.204135
# 479      Holland              51.503008               -0.204135
#
#              Venue                  Venue_id  Venue Latitude  Venue Longitude  \
# 470  The Belvedere  4ac518d6f964a5202aa820e3       51.501859        -0.204147
# 479     Flat Three  560709fe498e663eae00684d       51.506870        -0.207079
#
#           Venue Category
# 470           Restaurant
# 479  Japanese Restaurant

# %% [markdown]
# So a very limited number of restaurants in these two neighborhoods. Let's look at the ratings for these:

# %%
def getrating(venue_id):
    url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    result['response']['venue']
    try:
        print(result['response']['venue']['rating'])
    except:
        print('This venue has not been rated yet.')

# %%
for i in dalgarno_restaurants['Venue_id']:
    getrating(i)
# Out:
# 7.7
# This venue has not been rated yet.

# %%
for i in holland_restaurants['Venue_id']:
    getrating(i)
# Out:
# 7.9
# 7.4

# %% [markdown]
# We can see from the ratings that Holland has the more successful restaurants of the two neighborhoods and there are no other Italian restaurants nearby. Based on this analysis we could suggest to Mrs A that Holland, London would be a good location for a new Italian restaurant.
